# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv('/content/twitchdata-update.csv')
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
df.isnull().sum()
# Out:
# Channel                 0
# Watch time(Minutes)     0
# Stream time(minutes)    0
# Peak viewers            0
# Average viewers         0
# Followers               0
# Followers gained        0
# Views gained            0
# Partnered               0
# Mature                  0
# Language                0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure()
sns.barplot(data=df, x="Language", y="Stream time(minutes)")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
sns.barplot(x="Channel", y="Followers", data=df.sort_values("Followers", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
sns.barplot(x="Channel", y="Followers", data=df.sort_values("Followers", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
sns.barplot(x="Channel", y="Followers", data=df.sort_values("Followers", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="Partnered", data=df)
# Out:
# <Axes: xlabel='Partnered', ylabel='count'>

# %%
plt.figure()
sns.barplot(x="Channel", y="Views gained", data=df.sort_values("Views gained", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x="Mature", data=df)
# Out:
# <Axes: xlabel='Mature', ylabel='count'>

# %%
plt.figure()
sns.barplot(x="Channel", y="Average viewers", data=df.sort_values("Average viewers", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure()
sns.barplot(x="Channel", y="Stream time(minutes)", data=df.sort_values("Stream time(minutes)", ascending=False).head(20))
plt.xticks(rotation=90)
plt.show()

# %%
sns.lineplot(x="Stream time(minutes)", y="Followers gained", data=df)
# Out:
# <Axes: xlabel='Stream time(minutes)', ylabel='Followers gained'>

# %%
sns.lineplot(x="Stream time(minutes)", y="Average viewers", data=df)
# Out:
# <Axes: xlabel='Stream time(minutes)', ylabel='Average viewers'>

# %%
df[df["Watch time(Minutes)"] == df["Watch time(Minutes)"].max()]
# Out:
#   Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0   xQcOW           6196161750                215250        222720
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
#
#    Mature Language
# 0   False  English

# %%
df[df["Watch time(Minutes)"] == df["Watch time(Minutes)"].min()]
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 999    Remx            122192850                 99180         13788
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 999             1205     178553             59432       2049420       True
#
#      Mature Language
# 999   False   French

# %%
df[df["Stream time(minutes)"] == df["Stream time(minutes)"].max()]
# Out:
#       Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 392  RiffTrax            293583075                521445         24765
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 392              562      79099             17200       3313465       True
#
#      Mature Language
# 392   False  English

# %%
df[df["Stream time(minutes)"] == df["Stream time(minutes)"].min()]
# Out:
#       Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 990  KEEMSTAR            123365895                  3465         74195
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 990            35333     146035             46367       7139253      False
#
#      Mature Language
# 990   False  English

# %%
df[df["Peak viewers"] == df["Peak viewers"].max()]
# Out:
#                    Channel  Watch time(Minutes)  Stream time(minutes)  \
# 12  Riot Games (riotgames)           2674646715                 80820
#
#     Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 12        639375            20960    4487489            497678      56855694
#
#     Partnered  Mature Language
# 12       True   False  English

# %%
df[df["Peak viewers"] == df["Peak viewers"].min()]
# Out:
#         Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 890  Japan_ASMR            138935670                509670           496
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 890              271      67707             32649       1272641       True
#
#      Mature  Language
# 890   False  Japanese

# %%
df[df["Average viewers"] == df["Average viewers"].max()]
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 81  dota2ti           1017577605                  6315        483530
#
#     Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 81           147643     663297            121422      16228039       True
#
#     Mature Language
# 81   False  English

# %%
df[df["Average viewers"] == df["Average viewers"].min()]
# Out:
#         Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 992  RelaxBeats            123273930                521430          2830
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 992              235     166162             29595       1094850       True
#
#      Mature Language
# 992   False  English

# %%
df[df["Followers"] == df["Followers"].max()]
# Out:
#   Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 4    Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 4            29602    8938903           2068424      78998587       True
#
#    Mature Language
# 4   False  English

# %%
df[df["Followers"] == df["Followers"].min()]
# Out:
#      Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 758  voicetv            162510660                514845          1874
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 758              314       3660              1328       4001475       True
#
#      Mature Language
# 758   False     Thai

# %%
df[df["Views gained"] == df["Views gained"].min()]
# Out:
#      Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 794  Draineo            155593140                124095          7777
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 794             1169     102225             65702        175788       True
#
#      Mature Language
# 794   False  English

# %%
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Channel               1000 non-null   object
#  1   Watch time(Minutes)   1000 non-null   int64
#  2   Stream time(minutes)  1000 non-null   int64
#  3   Peak viewers          1000 non-null   int64
#  4   Average viewers       1000 non-null   int64
#  5   Followers             1000 non-null   int64
#  6   Followers gained      1000 non-null   int64
#  7   Views gained          1000 non-null   int64
#  8   Partnered             1000 non-null   bool
#  9   Mature                1000 non-null   bool
#  10  Language              1000 non-null   object
# dtypes: bool(2), int64(7), object(2)
# memory usage: 72.4+ KB

# %%
ndf = df.drop("Channel", axis=1)

# %%
ndf["Partnered"] = ndf["Partnered"].map({
    True: 1, False: 0
})

# %%
ndf["Mature"] = ndf["Mature"].map({
    True: 1, False: 0
})

# %%
ndf["Language"].value_counts()
# Out:
# English       485
# Korean         77
# Russian        74
# Spanish        68
# French         66
# Portuguese     61
# German         49
# Chinese        30
# Turkish        22
# Italian        17
# Polish         12
# Thai           11
# Japanese       10
# Czech           6
# Arabic          5
# Hungarian       2
# Slovak          1
# Other           1
# Greek           1
# Finnish         1
# Swedish         1
# Name: Language, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

def label_encoder(column):
    le = LabelEncoder().fit(column)
    print(column.name, le.classes_)
    return le.transform(column)

# %%
ndf["Language"] = label_encoder(ndf["Language"])
# Out:
# Language ['Arabic' 'Chinese' 'Czech' 'English' 'Finnish' 'French' 'German' 'Greek'
#  'Hungarian' 'Italian' 'Japanese' 'Korean' 'Other' 'Polish' 'Portuguese'
#  'Russian' 'Slovak' 'Spanish' 'Swedish' 'Thai' 'Turkish']

# %%
X = ndf.drop("Followers gained", axis=1)
y = ndf["Followers gained"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
X_test_scaled = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

linreg = LinearRegression()
linreg.fit(X_train_scaled, y_train)
y_pred = linreg.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.49701558975948923

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

lasso = Lasso()
lasso.fit(X_train_scaled, y_train)
y_pred = lasso.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.49701683824773935

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

ridge = Ridge()
ridge.fit(X_train_scaled, y_train)
y_pred = ridge.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.4970257533158471

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()
xgb.fit(X_train_scaled, y_train)
y_pred = xgb.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.466178917402431

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(X_train_scaled, y_train)
y_pred = rf.predict(X_test_scaled)
r2_score(y_test, y_pred)
# Out:
# 0.5069962893844455

# %%
import seaborn as sns
import pandas as pd

# Sample data (replace this with your data)
data = {
    'Feature1': [1, 2, 3, 4, 5, 6],
    'Feature2': [2, 3, 4, 5, 6, 7],
    'Feature3': [3, 4, 5, 6, 7, 8],
    'Feature4': [4, 5, 6, 7, 8, 9],
    'Target': [0, 1, 2, 0, 1, 2]  # Target label column
}

df = pd.DataFrame(data)

# Plot
sns.pairplot(df, hue='Target', palette='viridis')
plt.show()
